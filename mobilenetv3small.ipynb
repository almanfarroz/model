# %%
pip install tensorflow==2.17.1 keras==3.5.0
# Out:
# Requirement already satisfied: tensorflow==2.17.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (2.17.1)
# Requirement already satisfied: keras==3.5.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.17.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow==2.17.1) (2.17.1)
# Requirement already satisfied: absl-py in c:\laragon\bin\python\python-3.10\lib\site-packages (from keras==3.5.0) (2.2.2)
# Requirement already satisfied: numpy in c:\laragon\bin\python\python-3.10\lib\site-packages (from keras==3.5.0) (1.26.4)
# Requirement already satisfied: rich in c:\laragon\bin\python\python-3.10\lib\site-packages (from keras==3.5.0) (14.0.0)
# Requirement already satisfied: namex in c:\laragon\bin\python\python-3.10\lib\site-packages (from keras==3.5.0) (0.0.8)
# Requirement already satisfied: h5py in c:\laragon\bin\python\python-3.10\lib\site-packages (from keras==3.5.0) (3.13.0)
# Requirement already satisfied: optree in c:\laragon\bin\python\python-3.10\lib\site-packages (from keras==3.5.0) (0.15.0)
# Requirement already satisfied: ml-dtypes in c:\laragon\bin\python\python-3.10\lib\site-packages (from keras==3.5.0) (0.3.2)
# Requirement already satisfied: packaging in c:\users\alman\appdata\roaming\python\python310\site-packages (from keras==3.5.0) (24.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (4.25.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.32.3)
# Requirement already satisfied: setuptools in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (63.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\alman\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\alman\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.71.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.31.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from rich->keras==3.5.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alman\appdata\roaming\python\python310\site-packages (from rich->keras==3.5.0) (2.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.45.1)
# Requirement already satisfied: mdurl~=0.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras==3.5.0) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\laragon\bin\python\python-3.10\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\laragon\bin\python\python-3.10\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\laragon\bin\python\python-3.10\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\laragon\bin\python\python-3.10\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -eras (c:\laragon\bin\python\python-3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\laragon\bin\python\python-3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\laragon\bin\python\python-3.10\lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(tf.__version__)
# Out:
# 2.17.1

# %%
# Konfigurasi dataset
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 10
NUM_CLASSES = 54

# %%
# Load dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    'dataset/train',
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    'dataset/validation',
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=False
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    'dataset/test',
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=False
)

class_names = test_ds.class_names
# Out:
# Found 8478 files belonging to 54 classes.
# Found 1782 files belonging to 54 classes.
# Found 1782 files belonging to 54 classes.

# %%
for images, labels in train_ds.take(1):
    print("Image dtype:", images.dtype)
    print("Label dtype:", labels.dtype)
# Out:
# Image dtype: <dtype: 'float32'>
# Label dtype: <dtype: 'int32'>

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomRotation(0.1),
    layers.RandomTranslation(0.15, 0.15),
    layers.RandomZoom(0.2),
    layers.RandomFlip('horizontal')
])

# %%
AUTOTUNE = tf.data.AUTOTUNE

def prepare(ds, augment=False):
  # Normalization all datasets.
  ds = ds.map(lambda x, y: (x, y), 
              num_parallel_calls=AUTOTUNE)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, augment=True)
val_ds = prepare(val_ds)
test_ds = prepare(test_ds)

# %%
base_model = MobileNetV3Small(input_shape=(224, 224, 3), weights='imagenet', include_top=False, include_preprocessing=True)

base_model.trainable = False

# %%
model = tf.keras.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ MobileNetV3Small (Functional)   │ (None, 7, 7, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 576)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       147,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 54)             │        13,878 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,101,734 (4.20 MB)
#  Trainable params: 162,102 (633.21 KB)
#  Non-trainable params: 939,632 (3.58 MB)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
      train_ds,
      epochs=EPOCHS,
      verbose=2,
      validation_data=val_ds)
# Out:
# Epoch 1/10
# 265/265 - 14s - 53ms/step - accuracy: 0.5690 - loss: 1.6755 - val_accuracy: 0.8939 - val_loss: 0.4526
# Epoch 2/10
# 265/265 - 11s - 41ms/step - accuracy: 0.8247 - loss: 0.6401 - val_accuracy: 0.9220 - val_loss: 0.2893
# Epoch 3/10
# 265/265 - 11s - 41ms/step - accuracy: 0.8669 - loss: 0.4758 - val_accuracy: 0.9366 - val_loss: 0.2326
# Epoch 4/10
# 265/265 - 11s - 43ms/step - accuracy: 0.8892 - loss: 0.3891 - val_accuracy: 0.9304 - val_loss: 0.2400
# Epoch 5/10
# 265/265 - 12s - 44ms/step - accuracy: 0.8989 - loss: 0.3412 - val_accuracy: 0.9439 - val_loss: 0.1964
# Epoch 6/10
# 265/265 - 12s - 44ms/step - accuracy: 0.9053 - loss: 0.3172 - val_accuracy: 0.9444 - val_loss: 0.1908
# Epoch 7/10
# 265/265 - 12s - 44ms/step - accuracy: 0.9138 - loss: 0.2898 - val_accuracy: 0.9377 - val_loss: 0.1869
# Epoch 8/10
# 265/265 - 12s - 44ms/step - accuracy: 0.9199 - loss: 0.2617 - val_accuracy: 0.9416 - val_loss: 0.1942
# Epoch 9/10
# 265/265 - 20s - 77ms/step - accuracy: 0.9302 - loss: 0.2369 - val_accuracy: 0.9450 - val_loss: 0.1889
# Epoch 10/10
# 265/265 - 12s - 44ms/step - accuracy: 0.9284 - loss: 0.2425 - val_accuracy: 0.9495 - val_loss: 0.1740

# %%
results = pd.DataFrame(history.history)
print(results)
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.569002  1.675514      0.893939  0.452589
# 1  0.824723  0.640073      0.921998  0.289286
# 2  0.866950  0.475826      0.936588  0.232600
# 3  0.889243  0.389143      0.930415  0.239979
# 4  0.898915  0.341196      0.943883  0.196434
# 5  0.905284  0.317184      0.944444  0.190788
# 6  0.913777  0.289787      0.937710  0.186893
# 7  0.919910  0.261708      0.941639  0.194156
# 8  0.930172  0.236943      0.945006  0.188869
# 9  0.928403  0.242530      0.949495  0.174031

# %%
model.evaluate(test_ds, verbose=2)
# Out:
# 56/56 - 2s - 31ms/step - accuracy: 0.9456 - loss: 0.1755
# [0.17550669610500336, 0.9455667734146118]

# %%
# Plotting the training and testing loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# Plotting the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
# Confusion matrix dan classification report
true_labels = np.concatenate([y.numpy() for x, y in test_ds])
y_pred_probs = model.predict(test_ds, verbose=2)
y_pred_labels = np.argmax(y_pred_probs, axis=1)

cm = confusion_matrix(true_labels, y_pred_labels)

plt.figure(figsize=(25, 25))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 56/56 - 3s - 53ms/step

# %%
print('Classification Report:')
print(classification_report(true_labels, y_pred_labels, target_names=class_names))
# Out:
# Classification Report:
#                             precision    recall  f1-score   support
#
#            ABBOTTS BABBLER       0.97      0.88      0.92        33
#              ABBOTTS BOOBY       0.93      0.82      0.87        33
#       ASIAN OPENBILL STORK       0.92      1.00      0.96        33
#       AUSTRALASIAN FIGBIRD       0.80      0.97      0.88        33
#              BALI STARLING       0.97      0.97      0.97        33
#          BAR-TAILED GODWIT       0.84      0.97      0.90        33
#               BARN SWALLOW       0.94      0.88      0.91        33
# BLACK AND YELLOW BROADBILL       0.97      1.00      0.99        33
#                 BLACK BAZA       0.92      1.00      0.96        33
#        BORNEAN BRISTLEHEAD       1.00      0.97      0.98        33
#           BORNEAN LEAFBIRD       1.00      0.91      0.95        33
#                BROWN NOODY       0.94      0.97      0.96        33
#           BULWERS PHEASANT       1.00      0.91      0.95        33
#               CASPIAN TERN       0.94      0.94      0.94        33
#     CHESTNUT WINGED CUCKOO       0.89      0.97      0.93        33
#         CHINESE POND HERON       0.94      0.97      0.96        33
#                COMMON IORA       0.91      0.94      0.93        33
#         COPPERSMITH BARBET       0.97      0.88      0.92        33
#      CRESTED SERPENT EAGLE       0.94      0.88      0.91        33
#     CRESTED WOOD PARTRIDGE       1.00      0.91      0.95        33
#     DOUBLE EYED FIG PARROT       0.94      0.94      0.94        33
#                 DUSKY LORY       1.00      0.97      0.98        33
#              FIERY MINIVET       1.00      0.79      0.88        33
#             FOREST WAGTAIL       0.97      0.94      0.95        33
#                GLOSSY IBIS       0.94      1.00      0.97        33
#                GREAT ARGUS       0.94      0.94      0.94        33
#            GREEN BROADBILL       0.94      0.97      0.96        33
#     GREY HEADED FISH EAGLE       0.96      0.73      0.83        33
#          INDIGO FLYCATCHER       0.87      1.00      0.93        33
#               JAVA SPARROW       1.00      1.00      1.00        33
#            LESSER ADJUTANT       0.97      0.94      0.95        33
#               MAGPIE GOOSE       0.92      1.00      0.96        33
#                      MALEO       1.00      0.94      0.97        33
#             MASKED LAPWING       0.97      0.97      0.97        33
#             NICOBAR PIGEON       1.00      1.00      1.00        33
#            NOISY FRIARBIRD       0.91      0.88      0.89        33
#     ORANGE BREASTED TROGON       0.85      1.00      0.92        33
#           ORIENTAL BAY OWL       1.00      1.00      1.00        33
#                     OSPREY       0.85      1.00      0.92        33
#           PEREGRINE FALCON       0.97      0.97      0.97        33
#            POMARINE JAEGER       0.90      0.85      0.88        33
#      RED BEARDED BEE EATER       0.94      1.00      0.97        33
#                  ROCK DOVE       1.00      0.94      0.97        33
#            RUDY KINGFISHER       1.00      1.00      1.00        33
#            SAMATRAN THRUSH       1.00      0.97      0.98        33
#      SPOON BILED SANDPIPER       1.00      0.91      0.95        33
#     SPOTTED WHISTLING DUCK       0.82      1.00      0.90        33
#    STORK BILLED KINGFISHER       1.00      1.00      1.00        33
#    VICTORIA CROWNED PIGEON       1.00      1.00      1.00        33
#              VIOLET CUCKOO       0.86      0.94      0.90        33
#    WHITE BREASTED WATERHEN       1.00      0.91      0.95        33
#         WHITE BROWED CRAKE       0.97      0.97      0.97        33
#   WILSONS BIRD OF PARADISE       1.00      0.91      0.95        33
#                 ZEBRA DOVE       1.00      0.97      0.98        33
#
#                   accuracy                           0.95      1782
#                  macro avg       0.95      0.95      0.95      1782
#               weighted avg       0.95      0.95      0.95      1782

# %%
# Confusion matrix
cm = confusion_matrix(true_labels, y_pred_labels)
labels = class_names  # list nama kelas
results = []

# Inisialisasi untuk rata-rata
total_accuracy = 0
total_precision = 0
total_recall = 0
total_f1 = 0
total_test_data = 0

# Hitung metrik per kelas
for i, label in enumerate(labels):
    TP = cm[i, i]
    FP = cm[:, i].sum() - TP
    FN = cm[i, :].sum() - TP
    TN = cm.sum() - (TP + FP + FN)

    total = TP + FN
    total_test_data += total

    # Hitung metrik
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    # Akumulasi untuk rata-rata
    total_precision += precision
    total_recall += recall
    total_f1 += f1_score

    results.append({
        'Class': label,
        'Total': total,
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN,
        'Precision': round(precision, 4),
        'Recall': round(recall, 4),
        'F1-Score': round(f1_score, 4)
    })

# Hitung rata-rata
n_classes = len(labels)
avg_precision = total_precision / n_classes
avg_recall = total_recall / n_classes
avg_f1 = total_f1 / n_classes

# Tambahkan baris rata-rata ke DataFrame
results.append({
    'Class': 'Average',
    'Total': total_test_data,
    'TP': '-',
    'FP': '-',
    'FN': '-',
    'TN': '-',
    'Precision': round(avg_precision, 4),
    'Recall': round(avg_recall, 4),
    'F1-Score': round(avg_f1, 4)
})

# Buat DataFrame
metrics_df = pd.DataFrame(results)
metrics_df.to_excel('hasilmodel/cnn+mobilenet/small/confusion_metrics_mobilenetv3small.xlsx', index=False)

# %%
# Confusion matrix
cm = confusion_matrix(true_labels, y_pred_labels)

# Inisialisasi list untuk hasil
labels = class_names
results = []

# Hitung TP, FP, FN, TN untuk setiap kelas
for i, label in enumerate(labels):
    TP = cm[i, i]
    FP = cm[:, i].sum() - TP
    FN = cm[i, :].sum() - TP
    TN = cm.sum() - (TP + FP + FN)
    results.append({
        'Class': label,
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN
    })

# Buat dataframe
metrics_df = pd.DataFrame(results)

# Tampilkan tabel
print(metrics_df)

metrics_df.to_excel('hasilmodel/cnn+mobilenet/small/tidaklengkapconfusion_metrics_mobilenetv3small.xlsx', index=False)
# Out:
#                          Class  TP  FP  FN    TN
# 0              ABBOTTS BABBLER  29   1   4  1748
# 1                ABBOTTS BOOBY  27   2   6  1747
# 2         ASIAN OPENBILL STORK  33   3   0  1746
# 3         AUSTRALASIAN FIGBIRD  32   8   1  1741
# 4                BALI STARLING  32   1   1  1748
# 5            BAR-TAILED GODWIT  32   6   1  1743
# 6                 BARN SWALLOW  29   2   4  1747
# 7   BLACK AND YELLOW BROADBILL  33   1   0  1748
# 8                   BLACK BAZA  33   3   0  1746
# 9          BORNEAN BRISTLEHEAD  32   0   1  1749
# 10            BORNEAN LEAFBIRD  30   0   3  1749
# 11                 BROWN NOODY  32   2   1  1747
# 12            BULWERS PHEASANT  30   0   3  1749
# 13                CASPIAN TERN  31   2   2  1747
# 14      CHESTNUT WINGED CUCKOO  32   4   1  1745
# 15          CHINESE POND HERON  32   2   1  1747
# 16                 COMMON IORA  31   3   2  1746
# 17          COPPERSMITH BARBET  29   1   4  1748
# 18       CRESTED SERPENT EAGLE  29   2   4  1747
# 19      CRESTED WOOD PARTRIDGE  30   0   3  1749
# 20      DOUBLE EYED FIG PARROT  31   2   2  1747
# 21                  DUSKY LORY  32   0   1  1749
# 22               FIERY MINIVET  26   0   7  1749
# 23              FOREST WAGTAIL  31   1   2  1748
# 24                 GLOSSY IBIS  33   2   0  1747
# 25                 GREAT ARGUS  31   2   2  1747
# 26             GREEN BROADBILL  32   2   1  1747
# 27      GREY HEADED FISH EAGLE  24   1   9  1748
# 28           INDIGO FLYCATCHER  33   5   0  1744
# 29                JAVA SPARROW  33   0   0  1749
# 30             LESSER ADJUTANT  31   1   2  1748
# 31                MAGPIE GOOSE  33   3   0  1746
# 32                       MALEO  31   0   2  1749
# 33              MASKED LAPWING  32   1   1  1748
# 34              NICOBAR PIGEON  33   0   0  1749
# 35             NOISY FRIARBIRD  29   3   4  1746
# 36      ORANGE BREASTED TROGON  33   6   0  1743
# 37            ORIENTAL BAY OWL  33   0   0  1749
# 38                      OSPREY  33   6   0  1743
# 39            PEREGRINE FALCON  32   1   1  1748
# 40             POMARINE JAEGER  28   3   5  1746
# 41       RED BEARDED BEE EATER  33   2   0  1747
# 42                   ROCK DOVE  31   0   2  1749
# 43             RUDY KINGFISHER  33   0   0  1749
# 44             SAMATRAN THRUSH  32   0   1  1749
# 45       SPOON BILED SANDPIPER  30   0   3  1749
# 46      SPOTTED WHISTLING DUCK  33   7   0  1742
# 47     STORK BILLED KINGFISHER  33   0   0  1749
# 48     VICTORIA CROWNED PIGEON  33   0   0  1749
# 49               VIOLET CUCKOO  31   5   2  1744
# 50     WHITE BREASTED WATERHEN  30   0   3  1749
# 51          WHITE BROWED CRAKE  32   1   1  1748
# 52    WILSONS BIRD OF PARADISE  30   0   3  1749
# 53                  ZEBRA DOVE  32   0   1  1749

# %%
model.save('hasilmodel/cnn+mobilenet/small/mobilenetv3small.keras')

# %%
# Ambil nama folder dalam dataset/train sebagai label
class_names = sorted(os.listdir('dataset/train'))

# Simpan label ke dalam file labels.txt
with open('hasilmodel/cnn+mobilenet/small/labelssmall.txt', 'w') as f:
    for label in class_names:
        f.write(f'{label}\n')

print('Label mapping saved to labelssmall.txt')
# Out:
# Label mapping saved to labelssmall.txt
